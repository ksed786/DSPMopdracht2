# %%
#Import csv file from DSPM website, label column names and parse date format:
import pandas as pd
sales=pd.read_csv("http://liacs.leidenuniv.nl/~takesfw/DSPM/data/sales.csv", names=["saleId", "saleDateTime", "accountName", "coins", "currency", "priceInCurrency", "priceInEUR", "methodId", "ip", "ipCountry"], parse_dates=["saleDateTime"])

# %%
#Sort original csv file dates
sales = sales.sort_values(["saleDateTime"])

# %%
first = sales.groupby("accountName")["saleDateTime"].nsmallest(2)

# %%
last = sales.groupby("accountName")["saleDateTime"].nlargest(2)

# %%
firstamount = sales.groupby("accountName")['priceInEUR'].tail()
firstamount1 = firstamount.sum()
firstamount
# Out:
# 0         10.000000
# 5         10.000000
# 6         10.000000
# 15        10.000000
# 17        20.000000
# 21        10.000000
# 24        20.000000
# 25         5.000000
# 30        10.000000
# 31        10.000000
# 34        10.000000
# 40        20.000000
# 43        20.000000
# 46        10.000000
# 47        10.000000
# 48        10.000000
# 49        15.000000
# 52        20.000000
# 54         1.000000
# 56        10.000000
# 60        20.000000
# 61         5.000000
# 69        20.000000
# 70         5.000000
# 73        20.000000
# 74         5.000000
# 76        10.000000
# 77        30.000000
# 78         2.000000
# 79        20.000000
#             ...
# 747079    22.232000
# 747080     2.000000
# 747081     3.706000
# 747082     8.000000
# 747083     8.000000
# 747084     8.000000
# 747085    50.000000
# 747086     4.000000
# 747087     2.000000
# 747088     2.000000
# 747089     8.000000
# 747090     8.000000
# 747093     2.820270
# 747094     1.690000
# 747095    30.000000
# 747096     1.175113
# 747097     8.000000
# 747098     1.690000
# 747099     1.690000
# 747100     1.690000
# 747101     1.690000
# 747102     1.690000
# 747103     1.690000
# 747104     2.000000
# 747105     4.000000
# 747106     2.000000
# 747107     4.000000
# 747108     1.228000
# 747109     4.000000
# 747110    10.000000
# Name: priceInEUR, Length: 229350, dtype: float64

# %%
lastamount
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-40280e0e74d6> in <module>
# ----> 1 lastamount
#
# NameError: name 'lastamount' is not defined

# %%
def functie(x):
    q = True
    if x.iloc[0]['First'] < x.iloc[0]['Last']:
        q = False
    
    return q

temp1 = sales.groupby("accountName")["ipCountry"].nunique()
temp2 = sales.groupby("accountName")["saleDateTime"].max() - sales.groupby("accountName")["saleDateTime"].min()
temp3 = sales.groupby("accountName")["priceInEUR"].sum()
temp4 = sales.groupby("accountName")["saleId"].nunique()
tempx = sales.groupby("accountName")["ipCountry"].value_counts()
temp5 = tempx.groupby("accountName").idxmax().values
temp6 = [x[1] for x in temp5]
temp6
#tempy = sales.groupby("accountName")["methodId"].value_counts()
#temp6 = tempy.groupby("accountName").idxmax()

#temp7
##df = pd.DataFrame()
#df['First'] = abs(first.diff().reset_index().groupby("accountName").tail(1).set_index("accountName")["saleDateTime"].dt.days)
#df['Last'] = abs(last.diff().reset_index().groupby("accountName").tail(1).set_index("accountName")["saleDateTime"].dt.days)
#temp7 = df.groupby("accountName").apply(functie)
#temp7

#temp8
#d8 = pd.DataFrame()
#f['First'] = abs(first.diff().reset_index().groupby("accountName").tail(1).set_index("accountName")["saleDateTime"].dt.days)
#df['Last'] = abs(last.diff().reset_index().groupby("accountName").tail(1).set_index("accountName")["saleDateTime"].dt.days)
#temp7 = df.groupby("accountName").apply(functie)

#tempi = abs(first.diff().reset_index().groupby("accountName").tail(1).set_index("accountName")["saleDateTime"].dt.days)
#tempj = abs(last.diff().reset_index().groupby("accountName").tail(1).set_index("accountName")["saleDateTime"].dt.days)
#tempj
#sales.loc[sales["accountName"] == "000113b526fbc8d19f03fccb9"]
# Out:
# 0        FR
# 1        FR
# 2        NL
# 3        FR
# 4        PL
# 5        AU
# 6        US
# 7        IT
# 8        PR
# 9        BE
# 10       GB
# 11       DE
# 12       DE
# 13       FR
# 14       DE
# 15       GR
# 16       MQ
# 17       FR
# 18       RE
# 19       NL
# 20       GR
# 21       DE
# 22       MQ
# 23       NL
# 24       DE
# 25       DE
# 26       RO
# 27       GB
# 28       PL
# 29       SE
#          ..
# 76044    TR
# 76045    FR
# 76046    CY
# 76047    DE
# 76048    FR
# 76049    VE
# 76050    FR
# 76051    LU
# 76052    DE
# 76053    BE
# 76054    RO
# 76055    FR
# 76056    FR
# 76057    DE
# 76058    PL
# 76059    FR
# 76060    PL
# 76061    DE
# 76062    RE
# 76063    PT
# 76064    PT
# 76065    PT
# 76066    DE
# 76067    SE
# 76068    GR
# 76069    GB
# 76070    MQ
# 76071    GP
# 76072    CH
# 76073    FR
# Length: 76074, dtype: object

# %%
customers = pd.DataFrame()
customers['countries'] = temp1
customers['lifespan'] = temp2
customers['lifetime_spend'] = temp3
customers['lifetime_trans'] = temp4
# customers['fav_country'] = pd.Series([x[1] for x in tempx.groupby("accountName").idxmax()])
customers.append([x[1] for x in temp5])
#customers['fav_paymethod'] = temp6

customers
# Out:
#                            countries           lifespan  lifetime_spend  \
# accountName
# 000113b526fbc8d19f03fccb9          1   66 days 06:22:22          14.000
# 00027408fd5b8ff231814dbf2          1   27 days 15:43:48         431.780
# 0002c9dd969f5e5831d492524          1   83 days 09:35:55          40.000
# 0004dd02811925311678f7c85          1    0 days 23:26:42          21.690
# 00066a451be9a6bc5fda16fd9          1   76 days 20:48:49          24.050
# 0006801dfc7f8d682dd1b2b23          1    0 days 00:11:35           9.622
# 000697979068d5bbc49dbbd64          1    0 days 00:00:00          10.000
# 0006a7e0deb474b2c0339f38e          1  162 days 05:25:10         100.000
# 00081bff5faac28727d229ab2          1    0 days 00:00:00          10.000
# 0008709e543fee1af42062b9c          1  228 days 00:23:03          57.000
# 0008c60a0381b4bcc793436fd          1   89 days 22:21:33          13.612
# 000b49aef4fdca6601be00775          1  518 days 17:58:03          95.000
# 000ba55fec599714628aa4e3b          1  457 days 21:22:40          45.000
# 000e9e31fa555ca178e7ab025          2   50 days 06:15:13          26.900
# 000f5355d1554ff0bf926d6ab          1    9 days 17:39:58          27.880
# 000f831d32866742c0c93e1e7          1    0 days 00:00:00          10.000
# 0014881dea8cdbf6fdc3dc8e1          1   10 days 19:27:12          17.380
# accountName
# 000113b526fbc8d19f03fccb9               3         NaN
# 00027408fd5b8ff231814dbf2             120         NaN
# 0002c9dd969f5e5831d492524               5         NaN
# 0004dd02811925311678f7c85               5         NaN
# 00066a451be9a6bc5fda16fd9              17         NaN
# 0006801dfc7f8d682dd1b2b23               2         NaN
# 000697979068d5bbc49dbbd64               1         NaN
# 0006a7e0deb474b2c0339f38e              11         NaN
# 00081bff5faac28727d229ab2               1         NaN
# 0008709e543fee1af42062b9c               6         NaN
# 0008c60a0381b4bcc793436fd               4         NaN
# 000b49aef4fdca6601be00775              10         NaN
# 000ba55fec599714628aa4e3b               2         NaN
# 000e9e31fa555ca178e7ab025              15         NaN
# 000f5355d1554ff0bf926d6ab              12         NaN
# 000f831d32866742c0c93e1e7               1         NaN
# 0014881dea8cdbf6fdc3dc8e1               6         NaN
# 001820ed18e2e5987810cc1da              14         NaN
# 0018467de4d5cee6685cda843              18         NaN
# 001879062f1b4dea3719de128               1         NaN
# 0018ef6545d446d90df80a0d0               2         NaN
# 001987562fccee7fe4eb20f0c               3         NaN
# 001998acd85a26524fbdf22f9               2         NaN
# 0019ab20f5a35f0510524aaee               1         NaN
# 001a811d118a37c5e56633234               2         NaN
# 001bbecce468a9141c54e1f12               1         NaN
# 001c238e6f4fec64022163074               1         NaN
# 001d1c82b868b95c7c6df156a               1         NaN
# 001e01b2326898069d59344a0               2         NaN
# 001f56848117e34c5c3a025ec               4         NaN
# ...                                   ...         ...
# ffe8e4e285e4aca8e01256df4               2         NaN
# ffe9ac7f50f1acfb230d3fbd1              37         NaN
# ffeaa2d05f322212f85f5988f              31         NaN
# ffebce198cccc40f6275680bc              12         NaN
# ffec460ee76623fe1108a9ce5               4         NaN
# ffed3e0efe2e9a39b429cfbbb             126         NaN
# ffedbf6423c11b30e12f29dec              32         NaN
# ffeea3174463ede2f29d543ae               1         NaN
# ffef6877a5bf334b0f72d2dab              20         NaN
# fff037eb31502c0d7ac9be968               4         NaN
# fff1926e114083fa03aaad54e               2         NaN
# fff19edea1f8eba9265912a40              25         NaN
# fff249a4834b795a5077d0c4c              14         NaN
# fff25cbc38bb31a180809b05c               4         NaN
# fff34988f516f4c17e84fdc6c               2         NaN
# fff3597b7ff85e6ef60ccf26a               9         NaN
# fff44d0985646f6e196b7aa3c               8         NaN
# fff46c4ad99552dba7ec0765d               3         NaN
# fff4b42bf276ae64b38035bc0              58         NaN
# fff6413b2530563b24f2e2cde               7         NaN
# fff7bd9e5cb6846b89354d022               3         NaN
# fff836cc162e21cdbba10feb1               4         NaN
# fff8450fcbc698f4d61ab331c               1         NaN
# fff84b33ff8f662f6d01e9c64               4         NaN
# fff8cc5339049bf6ef2e50780              15         NaN
# fffaa6a39be1ab2f86fd2571f               1         NaN
# fffb2efd72b3318b86173d294               1         NaN
# fffcd5cce92731953647fe62f             139         NaN
# fffd3e63c839efd5435be9619               2         NaN
# fffdb7a076319ce6d46ec4ed8               8         NaN
#
# [76092 rows x 5 columns]
